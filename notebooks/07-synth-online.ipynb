# %% [markdown]
# # Online Data Augmentation during Training
#
# The previous notebook built extra series once, concatenated them to the training set, and then fitted NHITS. That is offline augmentation: the synthetic copies are fixed before training starts.
#
# Online augmentation does the same transformation inside the training loop. A PyTorch Lightning callback applies SeasonalMBB to each batch, concatenates the synthetic copies to that batch, and leaves the original training DataFrame unchanged. Because the bootstrap is redrawn every step, the network sees a different synthetic copy of the batch over the run.
#
# This notebook follows the **NeuralForecast** workflow from [Nixtla](https://github.com/Nixtla/neuralforecast). Data is a long DataFrame with `unique_id`, `ds`, and `y`. Two NHITS models share one `NeuralForecast` wrapper and the same training set. Only the second model gets the callback.
#
# The steps are as follows.
#
# 1. Load M3 monthly and split each series into train and a 24-month test window.
# 2. Wrap SeasonalMBB in `OnlineDataAugmentation`.
# 3. Fit NHITS and NHITS(MBB) on the same training set.
# 4. Rank both by test SMAPE.
#
# SeasonalMBB is the worked example. Any generator in `metaforecast.synth` can be passed to the callback.

# %%
import logging
import warnings

warnings.filterwarnings("ignore")
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)
logging.getLogger("lightning").setLevel(logging.ERROR)
logging.getLogger("lightning.pytorch").setLevel(logging.ERROR)

# %% [markdown]
# If necessary, install the package using pip:

# %%
# !pip install metaforecast

# %% [markdown]
# ## 1. Data preparation
#
# This tutorial uses the M3 monthly dataset from `datasetsforecast`. Horizon and input size (lags) are both 24 months.
#
# `SeriesWiseSplit.time_wise_split` keeps the last `horizon` observations of each series as the test set.

# %%
import pandas as pd
from datasetsforecast.m3 import M3

from metaforecast.evaluation.cv import SeriesWiseSplit

horizon = 24
n_lags = 24

df, *_ = M3.load(".", group="Monthly")
train_df, test_df = SeriesWiseSplit.time_wise_split(df, horizon=horizon)

print(train_df["unique_id"].nunique(), "series")
train_df.head()
# Out:
# 1428 series
#   unique_id         ds       y
# 0        M1 1990-01-31  2640.0
# 1        M1 1990-02-28  2640.0
# 2        M1 1990-03-31  2160.0
# 3        M1 1990-04-30  4200.0
# 4        M1 1990-05-31  3360.0

# %% [markdown]
# Sanity-check the split on series `M1000`. Training should end where the test window begins.

# %%
train_df.query('unique_id=="M1000"').tail()
# Out:
#     unique_id         ds       y
# 238     M1000 1991-10-31  4454.6
# 239     M1000 1991-11-30  4397.8
# 240     M1000 1991-12-31  4377.2
# 241     M1000 1992-01-31  4420.6
# 242     M1000 1992-02-29  4446.6

# %%
test_df.query('unique_id=="M1000"').head()
# Out:
#    unique_id         ds       y
# 72     M1000 1992-03-31  4451.8
# 73     M1000 1992-04-30  4496.0
# 74     M1000 1992-05-31  4494.8
# 75     M1000 1992-06-30  4505.8
# 76     M1000 1992-07-31  4501.2

# %% [markdown]
# ## 2. Online augmentation callback
#
# `OnlineDataAugmentation` is a Lightning callback. On each training batch it converts the tensor to a Nixtla DataFrame, runs `generator.transform`, concatenates the synthetic copy, and converts back to a tensor. The batch the model sees is larger; the training frame passed to `fit` is not rewritten.
#
# SeasonalMBB keeps trend and seasonality and resamples residual blocks of length `seas_period` (12 on monthly M3). Pass that generator into the callback.

# %%
from metaforecast.synth import OnlineDataAugmentation, SeasonalMBB

tsgen = SeasonalMBB(seas_period=12)
augmentation_cb = OnlineDataAugmentation(generator=tsgen)

# %% [markdown]
# ## 3. Model setup and fitting
#
# NHITS uses a small CPU config (`max_steps=1000`). Progress bars and Lightning logs are turned off.
#
# Both models train on `train_df`. The callback is passed only to the second NHITS. `alias` sets the forecast column names to `NHITS` and `NHITS(MBB)`.

# %%
from neuralforecast import NeuralForecast
from neuralforecast.models import NHITS

CONFIG = {
    "max_steps": 1000,
    "input_size": n_lags,
    "h": horizon,
    "accelerator": "cpu",
    "enable_progress_bar": False,
    "enable_model_summary": False,
    "logger": False,
}

nf = NeuralForecast(
    models=[
        NHITS(alias="NHITS", start_padding_enabled=True, **CONFIG),
        NHITS(
            alias="NHITS(MBB)",
            start_padding_enabled=True,
            callbacks=[augmentation_cb],
            **CONFIG,
        ),
    ],
    freq="ME",
)
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
# %%capture

nf.fit(df=train_df)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (mps), used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (mps), used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.

# %%
fcst = nf.predict(df=train_df)
fcst = fcst.drop(columns=["cutoff"], errors="ignore")
fcst.head()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (mps), used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (mps), used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
#   unique_id         ds        NHITS   NHITS(MBB)
# 0        M1 1993-09-30  2377.793457  2592.274658
# 1        M1 1993-10-31  2004.129150  2036.685547
# 2        M1 1993-11-30  2618.473389  2687.502930
# 3        M1 1993-12-31  2483.491211  2074.727783
# 4        M1 1994-01-31  2401.506104  2193.172852

# %% [markdown]
# Plot one series on the test window. Both models are trained on the same original series; the difference is whether SeasonalMBB ran on each training batch.

# %%
uid = "M1000"
obs = test_df.query("unique_id == @uid").set_index("ds")["y"]
hat = fcst.query("unique_id == @uid").set_index("ds")

ax = obs.plot(figsize=(12, 4), label="y")
hat["NHITS"].plot(ax=ax, label="NHITS")
hat["NHITS(MBB)"].plot(ax=ax, label="NHITS(MBB)")
ax.legend()
ax.set_title(f"{uid}: test window")
# Out:
# Text(0.5, 1.0, 'M1000: test window')

# %% [markdown]
# ## 4. Evaluation
#
# SMAPE on the 24-month test window, averaged over series. Lower is better.

# %%
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import smape

models = [c for c in fcst.columns if c not in ("unique_id", "ds")]
test_eval = test_df.merge(fcst, on=["unique_id", "ds"], how="left")
evaluation_df = evaluate(df=test_eval, metrics=[smape], models=models)
evaluation_df.head()
# Out:
#   unique_id metric     NHITS  NHITS(MBB)
# 0        M1  smape  0.236779    0.236937
# 1       M10  smape  0.117557    0.110202
# 2      M100  smape  0.043614    0.045951
# 3     M1000  smape  0.008055    0.006890
# 4     M1001  smape  0.017427    0.018812

# %%
mean_smape = evaluation_df.drop(columns=["metric", "unique_id"]).mean().sort_values()
mean_smape
# Out:
# NHITS(MBB)    0.072655
# NHITS         0.072838
# dtype: float64
