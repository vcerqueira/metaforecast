# %% [markdown]
# # Long-horizon Forecasting with FTN
#
# Forecast accuracy usually drops as the horizon grows. Recursive multi-step methods propagate error; direct methods treat each step as independent. **FTN** (Forecast Trajectory Neighbors) is an instance-based correction: it matches a model's forecast path to similar trajectories in the training history (KNN) and replaces the path with the neighbors' continuation.
#
# This notebook follows the **NeuralForecast** workflow from [Nixtla](https://github.com/Nixtla/neuralforecast). Data is a long DataFrame with `unique_id`, `ds`, and `y`. NHITS is trained with `NeuralForecast.fit` / `predict`. FTN from `metaforecast.longhorizon` post-processes those forecasts.
#
# The steps are as follows.
#
# 1. Load ETTm2 (15-minute) from the LongHorizon collection.
# 2. Split each series into train and a 360-step test window (6 hours).
# 3. Fit NHITS on the training set.
# 4. Fit FTN on the same training series and correct the NHITS forecasts.
# 5. Rank NHITS and NHITS(FTN) by SMAPE.
#
# Weighting FTN by horizon (so short-term steps stay close to NHITS) is in the next notebook.

# %%
import logging
import warnings

warnings.filterwarnings("ignore")
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)
logging.getLogger("lightning").setLevel(logging.ERROR)
logging.getLogger("lightning.pytorch").setLevel(logging.ERROR)

# %% [markdown]
# If necessary, install the package using pip:

# %%
# !pip install metaforecast

# %% [markdown]
# ## 1. Data preparation
#
# ETTm2 is a 15-minute electricity transformer series from `datasetsforecast.long_horizon`. Horizon and input size are 360 steps (6 hours).
#
# `SeriesWiseSplit.time_wise_split` keeps the last `horizon` observations of each series as the test set.

# %%
import pandas as pd
from datasetsforecast.long_horizon import LongHorizon

from metaforecast.evaluation.cv import SeriesWiseSplit

horizon = 360
n_lags = 360

df, *_ = LongHorizon.load(".", group="ETTm2")
df["ds"] = pd.to_datetime(df["ds"])

train_df, test_df = SeriesWiseSplit.time_wise_split(df, horizon=horizon)

print(train_df["unique_id"].nunique(), "series")
train_df.head()
# Out:
# 100%|██████████| 314M/314M [00:21<00:00, 14.7MiB/s]
# INFO:datasetsforecast.utils:Successfully downloaded datasets.zip, 314116557, bytes.
# INFO:datasetsforecast.utils:Decompressing zip file...
# INFO:datasetsforecast.utils:Successfully decompressed longhorizon/datasets/datasets.zip
# 7 series
#   unique_id                  ds         y
# 0      HUFL 2016-07-01 00:00:00 -0.041413
# 1      HUFL 2016-07-01 00:15:00 -0.185467
# 2      HUFL 2016-07-01 00:30:00 -0.257495
# 3      HUFL 2016-07-01 00:45:00 -0.577510
# 4      HUFL 2016-07-01 01:00:00 -0.385501

# %% [markdown]
# Sanity-check the split on series `HUFL`. Training should end where the test window begins.

# %%
train_df.query('unique_id=="HUFL"').tail()
# Out:
#       unique_id                  ds         y
# 57235      HUFL 2018-02-17 04:45:00 -2.265949
# 57236      HUFL 2018-02-17 05:00:00 -2.001912
# 57237      HUFL 2018-02-17 05:15:00 -1.945934
# 57238      HUFL 2018-02-17 05:30:00 -2.089988
# 57239      HUFL 2018-02-17 05:45:00 -2.145967

# %%
test_df.query('unique_id=="HUFL"').head()
# Out:
#   unique_id                  ds         y
# 0      HUFL 2018-02-17 06:00:00 -1.881931
# 1      HUFL 2018-02-17 06:15:00 -1.953862
# 2      HUFL 2018-02-17 06:30:00 -1.945934
# 3      HUFL 2018-02-17 06:45:00 -1.857858
# 4      HUFL 2018-02-17 07:00:00 -2.033914

# %% [markdown]
# ## 2. NHITS
#
# NHITS is a strong default for long-horizon problems. The config is kept small (`max_steps=1000`, CPU) so the notebook is easy to re-run. Progress bars and Lightning logs are turned off.

# %%
from neuralforecast import NeuralForecast
from neuralforecast.models import NHITS

CONFIG = {
    "max_steps": 1000,
    "input_size": n_lags,
    "h": horizon,
    "accelerator": "cpu",
    "enable_progress_bar": False,
    "enable_model_summary": False,
    "logger": False,
}

nf = NeuralForecast(
    models=[NHITS(start_padding_enabled=True, **CONFIG)],
    freq="15min",
)
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
# %%capture

nf.fit(df=train_df)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (mps), used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=1000` reached.

# %% [markdown]
# ## 3. Fitting FTN
#
# FTN fits a KNN per `unique_id` on rolling trajectories from the training series. `n_neighbors=150` is a wide neighborhood for this long window. `apply_ewm=True` smooths the series before matching so noise is less likely to dominate the neighbors.
#
# `predict` takes the NeuralForecast frame (`unique_id`, `ds`, `NHITS`) and adds an `NHITS(FTN)` column.

# %%
from metaforecast.longhorizon import MLForecastFTN as FTN

ftn = FTN(horizon=horizon, n_neighbors=150, apply_ewm=True)
ftn.fit(train_df)
# Out:
# 100%|██████████| 7/7 [00:02<00:00,  2.81it/s]

# %%
fcst_nf = nf.predict()
if "unique_id" not in fcst_nf.columns:
    fcst_nf = fcst_nf.reset_index()

fcst_ftn = ftn.predict(fcst_nf)
fcst_ftn.head()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (mps), used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# 100%|██████████| 7/7 [00:00<00:00, 10.91it/s]
#   unique_id                  ds     NHITS  NHITS(FTN)
# 0      HUFL 2018-02-17 06:00:00 -2.119768   -1.777224
# 1      HUFL 2018-02-17 06:15:00 -2.106963   -1.780553
# 2      HUFL 2018-02-17 06:30:00 -2.081670   -1.782140
# 3      HUFL 2018-02-17 06:45:00 -2.062570   -1.782167
# 4      HUFL 2018-02-17 07:00:00 -2.048575   -1.780866

# %% [markdown]
# Plot one series on the test window. FTN should mainly change the later steps of the path.

# %%
uid = "HUFL"
obs = test_df.query("unique_id == @uid").set_index("ds")["y"]
hat = fcst_ftn.query("unique_id == @uid").set_index("ds")

ax = obs.plot(figsize=(12, 4), label="y")
hat["NHITS"].plot(ax=ax, label="NHITS")
hat["NHITS(FTN)"].plot(ax=ax, label="NHITS(FTN)")
ax.legend()
ax.set_title(f"{uid}: test window")
# Out:
# Text(0.5, 1.0, 'HUFL: test window')

# %% [markdown]
# ## 4. Evaluation
#
# SMAPE on the 360-step test window, averaged over series. Lower is better.

# %%
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import smape

test_eval = test_df.merge(fcst_ftn, on=["unique_id", "ds"], how="left")
models = [c for c in fcst_ftn.columns if c not in ("unique_id", "ds")]

evaluation_df = evaluate(df=test_eval, metrics=[smape], models=models)
evaluation_df
# Out:
#   unique_id metric     NHITS  NHITS(FTN)
# 0      HUFL  smape  0.097150    0.086934
# 1      HULL  smape  0.123572    0.131510
# 2      LUFL  smape  0.023759    0.022417
# 3      LULL  smape  0.336334    0.220572
# 4      MUFL  smape  0.120401    0.122025
# 5      MULL  smape  0.105452    0.109104
# 6        OT  smape  0.114611    0.114282

# %%
mean_smape = evaluation_df.drop(columns=["metric", "unique_id"]).mean().sort_values()
mean_smape
# Out:
# NHITS(FTN)    0.115263
# NHITS         0.131611
# dtype: float64
